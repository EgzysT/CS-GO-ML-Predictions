# %%
# IPython magic
# %config IPCompleter.greedy=True

# Import other notebooks
import import_ipynb
from DataLoader import *

# Imports
import pandas as pd
import json
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# Pandas settings
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
# Out:
# importing Jupyter notebook from DataLoader.ipynb

# %%
# Loading and cleaning bad data lines
dfInitial = loadDataset("dataset_initial", 17)
# dfSecond = loadDataset("dataset_second", 6)
# Out:
# dataset_initial/dataset_00.json
# dataset_initial/dataset_01.json
# dataset_initial/dataset_02.json
# dataset_initial/dataset_03.json
# dataset_initial/dataset_04.json
# dataset_initial/dataset_05.json
# dataset_initial/dataset_06.json
# dataset_initial/dataset_07.json
# dataset_initial/dataset_08.json
# dataset_initial/dataset_09.json
# dataset_initial/dataset_10.json
# dataset_initial/dataset_11.json
# dataset_initial/dataset_12.json
# dataset_initial/dataset_13.json
# dataset_initial/dataset_14.json
# dataset_initial/dataset_15.json
# dataset_initial/dataset_16.json
# dataset_initial/dataset_17.json
# Rejected data:
#           map  CT_score  T_score round_status  round_status_time_left  CT_total_health  T_total_health  CT_num_alive_players  T_num_alive_players  CT_equip_value  T_equip_value  CT_money  T_money  CT_has_Defuser bomb_site  bomb_dropped round_winner
# 0    de_train         5        0   FreezeTime                    20.0              500             600                     5                    6          5100.0           1200     40050    21550            True      None         False           CT
# 1  de_vertigo         0        0   FreezeTime                    20.0              500             600                     5                    6          1000.0           1200      4000     4800           False      None         False    Terrorist

# %%
display(dfInitial)
# Out:
#              map CT_score T_score round_status  round_status_time_left CT_total_health T_total_health CT_num_alive_players T_num_alive_players  CT_equip_value T_equip_value CT_money T_money CT_has_Defuser bomb_site bomb_dropped round_winner  fileNumber  indexInFile                                              Debug
# 0       de_dust2        0       0   FreezeTime               20.000000             500            500                    5                   5          1000.0          1000     4000    4000          False      None        False           CT         0.0          0.0  {"map":"de_dust2","patch_version":13737,"map_c...
# 1       de_dust2        0       0   FreezeTime                1.031250             500            500                    5                   5          4400.0          4350      600     650           True      None        False           CT         0.0          1.0  {"map":"de_dust2","patch_version":13737,"map_c...
# 2       de_dust2        0       0       Normal               96.031250             391            400                    4                   4          3511.0          3300      750     500           True      None        False           CT         0.0          2.0  {"map":"de_dust2","patch_version":13737,"map_c...
# 3       de_dust2        0       0       Normal               76.031250             391            400                    4                   4          3111.0          2100      750     500           True      None        False           CT         0.0          3.0  {"map":"de_dust2","patch_version":13737,"map_c...
# 4       de_dust2        1       0   FreezeTime               19.968750             500            500                    5                   5          2648.0          1000    18350   10750           True      None        False           CT         0.0          4.0  {"map":"de_dust2","patch_version":13737,"map_c...
# ...          ...      ...     ...          ...                     ...             ...            ...                  ...                 ...             ...           ...      ...     ...            ...       ...          ...          ...         ...          ...                                                ...
# 87125  de_mirage       15      14       Normal               94.953125             334            413                    5                   5         26990.0         22300    13800     300           True      None         True           CT        17.0        547.0  {"map":"de_mirage","patch_version":13718,"map_...
# 87126  de_mirage       15      14       Normal               74.953125             334            400                    5                   4         24990.0         17500    14100     150           True      None         True           CT        17.0        548.0  {"map":"de_mirage","patch_version":13718,"map_...
# 87127  de_mirage       15      14       Normal               54.953125             334            400                    5                   4         24990.0         17100    14100     150           True      None         True           CT        17.0        549.0  {"map":"de_mirage","patch_version":13718,"map_...
# 87128  de_mirage       15      14       Normal               34.953125             334            400                    5                   4         24990.0         17100    14100     150           True      None        False           CT        17.0        550.0  {"map":"de_mirage","patch_version":13718,"map_...
# 87129  de_mirage       15      14       Normal               14.953125             237            373                    4                   4         20530.0         16400    10500     450           True      None        False           CT        17.0        551.0  {"map":"de_mirage","patch_version":13718,"map_...
#
# [87130 rows x 20 columns]

# %%
df2 = dfInitial.copy()
df2["map"] = df2["map"].astype("category")
df2["mapCodes"] = df2["map"].cat.codes

df2["CT_score"] = pd.to_numeric(df2["CT_score"], downcast="unsigned")
df2["T_score"] = pd.to_numeric(df2["T_score"], downcast="unsigned")

df2["round_status"] = df2["round_status"].astype("category")
df2["round_status_codes"] = df2["round_status"].cat.codes

df2["CT_total_health"] = pd.to_numeric(df2["CT_total_health"], downcast="unsigned")
df2["T_total_health"] = pd.to_numeric(df2["T_total_health"], downcast="unsigned")
df2["CT_num_alive_players"] = pd.to_numeric(df2["CT_num_alive_players"], downcast="unsigned")
df2["T_num_alive_players"] = pd.to_numeric(df2["T_num_alive_players"], downcast="unsigned")
df2["CT_equip_value"] = pd.to_numeric(df2["CT_equip_value"], downcast="unsigned")
df2["T_equip_value"] = pd.to_numeric(df2["T_equip_value"], downcast="unsigned")
df2["CT_money"] = pd.to_numeric(df2["CT_money"], downcast="unsigned")
df2["T_money"] = pd.to_numeric(df2["T_money"], downcast="unsigned")

df2["CT_has_Defuser"] = df2["CT_has_Defuser"].astype("bool")

df2["bomb_site"] = df2["bomb_site"].astype("category")
df2["bomb_site_codes"] = df2["bomb_site"].astype("category").cat.codes

df2["bomb_dropped"] = df2["bomb_dropped"].astype("bool")

df2["round_winner"] = df2["round_winner"].astype("category")
df2["round_winner_codes"] = df2["round_winner"].cat.codes

df2["fileNumber"] = pd.to_numeric(df2["fileNumber"], downcast="unsigned")
df2["indexInFile"] = pd.to_numeric(df2["indexInFile"], downcast="unsigned")

# %%
df2.dtypes
# Out:
# map                       category
# CT_score                     uint8
# T_score                      uint8
# round_status              category
# round_status_time_left     float64
# CT_total_health             uint16
# T_total_health              uint16
# CT_num_alive_players         uint8
# T_num_alive_players          uint8
# CT_equip_value             float64
# T_equip_value               uint16
# CT_money                    uint32
# T_money                     uint32
# CT_has_Defuser                bool
# bomb_site                 category
# bomb_dropped                  bool
# round_winner              category
# fileNumber                   uint8
# indexInFile                 uint16
# Debug                       object
# mapCodes                      int8
# round_status_codes            int8
# bomb_site_codes               int8
# round_winner_codes            int8
# dtype: object

# %%
# check for balance of classes
df2['round_winner'].value_counts()
# Out:
# Terrorist    44522
# CT           42608
# Name: round_winner, dtype: int64

# %%
df2.memory_usage(deep=True)
# Out:
# Index                           128
# map                           87977
# CT_score                      87130
# T_score                       87130
# round_status                  87408
# round_status_time_left       697040
# CT_total_health              174260
# T_total_health               174260
# CT_num_alive_players          87130
# T_num_alive_players           87130
# CT_equip_value               697040
# T_equip_value                174260
# CT_money                     348520
# T_money                      348520
# CT_has_Defuser                87130
# bomb_site                     87326
# bomb_dropped                  87130
# round_winner                  87335
# fileNumber                    87130
# indexInFile                  174260
# Debug                     506249769
# mapCodes                      87130
# round_status_codes            87130
# bomb_site_codes               87130
# round_winner_codes            87130
# dtype: int64

# %%
X = df2[['mapCodes', 'CT_score', 'T_score', 'round_status_codes', 'round_status_time_left', 'CT_total_health', 'T_total_health', 'CT_num_alive_players', 'T_num_alive_players', 'CT_equip_value', 'CT_money', 'T_money','T_equip_value', 'CT_has_Defuser', 'bomb_site_codes', 'bomb_dropped']]
y = df2['round_winner_codes']

#Splitting the train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training / 30% testing data

clf=RandomForestClassifier(n_estimators=100, n_jobs=-1)

clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

print("Accuracy: ", metrics.accuracy_score(y_test, y_pred))
print("Precision: ", metrics.precision_score(y_test, y_pred))
print("ROC_AUC: ", metrics.roc_auc_score(y_test, y_pred))
# Out:
# Accuracy:  0.7846895443590037
# Precision:  0.8003560922743459
# ROC_AUC:  0.7850000463943647

# %%
model = RandomForestClassifier(n_estimators=100, n_jobs=-1)

cv_results = cross_validate(model, X, y, cv=5, scoring=('accuracy', 'precision', 'roc_auc', 'f1'))

# %%
cv_results
# Out:
# {'fit_time': array([1.97121072, 1.91710854, 2.01410127, 1.95220304, 2.03251982]),
#  'score_time': array([0.30604982, 0.34998989, 0.35292435, 0.34497786, 0.22897005]),
#  'test_accuracy': array([0.69597154, 0.68868358, 0.69826696, 0.70423505, 0.69516814]),
#  'test_precision': array([0.71023787, 0.70028785, 0.71276844, 0.72769212, 0.71217669]),
#  'test_roc_auc': array([0.79027528, 0.7825196 , 0.79217794, 0.79927968, 0.79081616]),
#  'test_f1': array([0.69691076, 0.69156859, 0.69906136, 0.69933497, 0.69422058])}

# %%
df2.describe()
# Out:
#            CT_score       T_score  round_status_time_left  CT_total_health  T_total_health  CT_num_alive_players  T_num_alive_players  CT_equip_value  T_equip_value      CT_money       T_money    fileNumber   indexInFile      mapCodes  round_status_codes  bomb_site_codes  round_winner_codes
# count  87130.000000  87130.000000            87130.000000     87130.000000    87130.000000          87130.000000         87130.000000    87130.000000   87130.000000  87130.000000  87130.000000  87130.000000  87130.000000  87130.000000        87130.000000     87130.000000        87130.000000
# mean       6.836692      6.938758               55.675830       410.275852      400.529565              4.259130             4.247263    15384.861885   14104.865718  10028.436819  11502.646046      8.059853   2531.790003      3.527488            1.510134        -0.832457            0.510984
# std        4.884465      4.830990               36.552743       133.167058      140.858375              1.213844             1.238831    10156.203573    9182.779130  11487.235421  12482.261294      4.934513   1476.987845      1.940580            0.689879         0.498528            0.499882
# min        0.000000      0.000000                0.007812         0.000000        0.000000              0.000000             0.000000        0.000000       0.000000      0.000000      0.000000      0.000000      0.000000      0.000000            0.000000        -1.000000            0.000000
# 25%        3.000000      3.000000               19.953125       343.000000      314.000000              4.000000             4.000000     5100.000000    4400.000000   1350.000000   1650.000000      4.000000   1248.000000      2.000000            1.000000        -1.000000            0.000000
# 50%        6.000000      6.000000               54.804688       500.000000      500.000000              5.000000             5.000000    15457.250000   14900.000000   5800.000000   7350.000000      8.000000   2530.000000      3.000000            2.000000        -1.000000            1.000000
# 75%       10.000000     10.000000               94.843750       500.000000      500.000000              5.000000             5.000000    24628.875000   22500.000000  14900.000000  18350.000000     12.000000   3811.000000      5.000000            2.000000        -1.000000            1.000000
# max       32.000000     33.000000              115.000000       500.000000      500.000000              5.000000             5.000000    39340.000000   36150.000000  80000.000000  80000.000000     17.000000   5159.000000      7.000000            2.000000         1.000000            1.000000

# %%
df2[(df2['T_money'] >= 80000) | (df2['CT_money'] >= 80000)]
# Out:
#               map  CT_score  T_score round_status  round_status_time_left  CT_total_health  T_total_health  CT_num_alive_players  T_num_alive_players  CT_equip_value  T_equip_value  CT_money  T_money  CT_has_Defuser bomb_site  bomb_dropped round_winner  fileNumber  indexInFile                                              Debug  mapCodes  round_status_codes  bomb_site_codes  round_winner_codes
# 2579   de_inferno        15       15   FreezeTime               20.000000              500             500                     5                    5          9650.0           1000     80000    80000           False       NaN         False    Terrorist           0         2579  {"map":"de_inferno","patch_version":13703,"map...         2                   1               -1                   1
# 2599   de_inferno        17       16   FreezeTime               20.000000              500             500                     5                    5          4000.0           1000     80000    80000           False       NaN         False    Terrorist           0         2599  {"map":"de_inferno","patch_version":13703,"map...         2                   1               -1                   1
# 2600   de_inferno        17       16   FreezeTime               15.304688              500             500                     5                    5          1000.0          15500     80000    65500           False       NaN         False    Terrorist           0         2600  {"map":"de_inferno","patch_version":13703,"map...         2                   1               -1                   1
# 2621   de_inferno        18       18   FreezeTime               20.000000              500             500                     5                    5          9550.0           1000     80000    80000           False       NaN         False           CT           0         2621  {"map":"de_inferno","patch_version":13703,"map...         2                   1               -1                   0
# 2640   de_inferno        20       19   FreezeTime               20.000000              500             500                     5                    5         13900.0           1000     80000    80000           False       NaN         False           CT           0         2640  {"map":"de_inferno","patch_version":13703,"map...         2                   1               -1                   0
# ...           ...       ...      ...          ...                     ...              ...             ...                   ...                  ...             ...            ...       ...      ...             ...       ...           ...          ...         ...          ...                                                ...       ...                 ...              ...                 ...
# 85830    de_dust2        15       15   FreezeTime               16.406250              500             500                     5                    5         10150.0           1000     70850    80000            True       NaN         False           CT          16         4372  {"map":"de_dust2","patch_version":13703,"map_c...         1                   1               -1                   0
# 85831    de_dust2        15       15   FreezeTime               20.000000              500             500                     5                    5         33000.0           1000     48000    80000            True       NaN         False           CT          16         4373  {"map":"de_dust2","patch_version":13703,"map_c...         1                   1               -1                   0
# 85851    de_dust2        17       16   FreezeTime               20.000000              500             500                     5                    5          4300.0           1000     80000    80000           False       NaN         False    Terrorist          16         4393  {"map":"de_dust2","patch_version":13703,"map_c...         1                   1               -1                   1
# 85872    de_dust2        18       18   FreezeTime               20.000000              500             500                     5                    5          4400.0           1000     80000    80000           False       NaN         False    Terrorist          16         4414  {"map":"de_dust2","patch_version":13703,"map_c...         1                   1               -1                   1
# 85893    de_dust2        21       18   FreezeTime               20.000000              500             500                     5                    5          8100.0           1000     80000    80000           False       NaN         False    Terrorist          16         4435  {"map":"de_dust2","patch_version":13703,"map_c...         1                   1               -1                   1
#
# [117 rows x 24 columns]

# %%
# num of overtime screenshots
df2[(df2['CT_score'] >= 16) | (df2['T_score'] >= 16)]
# Out:
#               map  CT_score  T_score round_status  round_status_time_left  CT_total_health  T_total_health  CT_num_alive_players  T_num_alive_players  CT_equip_value  T_equip_value  CT_money  T_money  CT_has_Defuser bomb_site  bomb_dropped round_winner  fileNumber  indexInFile                                              Debug  mapCodes  round_status_codes  bomb_site_codes  round_winner_codes
# 2586   de_inferno        15       16   FreezeTime               19.929688              500             500                     5                    5          1000.0           4700     58900    71450           False       NaN         False           CT           0         2586  {"map":"de_inferno","patch_version":13703,"map...         2                   1               -1                   0
# 2587   de_inferno        15       16       Normal              114.937500              500             500                     5                    5         33550.0          28250     25950    48650            True       NaN         False           CT           0         2587  {"map":"de_inferno","patch_version":13703,"map...         2                   2               -1                   0
# 2588   de_inferno        15       16       Normal               94.937500              373             448                     4                    5         25040.0          25950     21650    48450            True       NaN          True           CT           0         2588  {"map":"de_inferno","patch_version":13703,"map...         2                   2               -1                   0
# 2589   de_inferno        15       16       Normal               74.937500              373             348                     4                    4         25040.0          20650     21750    39300            True       NaN         False           CT           0         2589  {"map":"de_inferno","patch_version":13703,"map...         2                   2               -1                   0
# 2590   de_inferno        15       16       Normal               54.937500              373             348                     4                    4         24740.0          19450     21750    39300            True       NaN         False           CT           0         2590  {"map":"de_inferno","patch_version":13703,"map...         2                   2               -1                   0
# ...           ...       ...      ...          ...                     ...              ...             ...                   ...                  ...             ...            ...       ...      ...             ...       ...           ...          ...         ...          ...                                                ...       ...                 ...              ...                 ...
# 85900    de_dust2        21       19   FreezeTime               19.906250              500             500                     5                    5          1000.0          15950     56650    67350           False       NaN         False           CT          16         4442  {"map":"de_dust2","patch_version":13703,"map_c...         1                   1               -1                   0
# 85901    de_dust2        21       19       Normal              114.937500              500             500                     5                    5         33100.0          28850     24350    54500            True       NaN         False           CT          16         4443  {"map":"de_dust2","patch_version":13703,"map_c...         1                   2               -1                   0
# 85902    de_dust2        21       19       Normal               94.937500              400             368                     4                    4         25800.0          21350     17350    47700            True       NaN         False           CT          16         4444  {"map":"de_dust2","patch_version":13703,"map_c...         1                   2               -1                   0
# 85903    de_dust2        21       19       Normal               74.937500              200             153                     2                    3         11900.0          15650      9000    34450            True       NaN         False           CT          16         4445  {"map":"de_dust2","patch_version":13703,"map_c...         1                   2               -1                   0
# 85904    de_dust2        21       19  BombPlanted               24.906250              200              53                     2                    2         11000.0           8800      9300    23550            True         A         False           CT          16         4446  {"map":"de_dust2","patch_version":13703,"map_c...         1                   0                0                   0
#
# [2490 rows x 24 columns]

# %%
df2[((df2['T_money'] == 50000) | (df2['CT_money'] == 50000)) & (df2['round_status'] != 'FreezeTime')]
# Out:
#                map  CT_score  T_score round_status  round_status_time_left  CT_total_health  T_total_health  CT_num_alive_players  T_num_alive_players  CT_equip_value  T_equip_value  CT_money  T_money  CT_has_Defuser bomb_site  bomb_dropped round_winner  fileNumber  indexInFile                                              Debug  mapCodes  round_status_codes  bomb_site_codes  round_winner_codes
# 38866  de_overpass         4        6       Normal               114.89844              500             500                     5                    5         26450.0          28350       700    50000           False       NaN         False           CT           7         3267  {"map":"de_overpass","patch_version":13740,"ma...         5                   2               -1                   0
# 38867  de_overpass         4        6       Normal                94.89844              500             482                     5                    5         24250.0          27450       700    50000           False       NaN         False           CT           7         3268  {"map":"de_overpass","patch_version":13740,"ma...         5                   2               -1                   0

# %%
df2.loc[38860:38873]
# Out:
#                map  CT_score  T_score round_status  round_status_time_left  CT_total_health  T_total_health  CT_num_alive_players  T_num_alive_players  CT_equip_value  T_equip_value  CT_money  T_money  CT_has_Defuser bomb_site  bomb_dropped round_winner  fileNumber  indexInFile                                              Debug  mapCodes  round_status_codes  bomb_site_codes  round_winner_codes
# 38860  de_overpass         4        5   FreezeTime               19.976562              500             500                     5                    5          5600.0          28050     14150    38300           False       NaN         False    Terrorist           7         3261  {"map":"de_overpass","patch_version":13740,"ma...         5                   1               -1                   1
# 38861  de_overpass         4        5       Normal              114.976560              500             500                     5                    5          5600.0          28050     14150    38300           False       NaN         False    Terrorist           7         3262  {"map":"de_overpass","patch_version":13740,"ma...         5                   2               -1                   1
# 38862  de_overpass         4        5       Normal               94.976560              463             492                     5                    5          5600.0          26150     14150    38300           False       NaN          True    Terrorist           7         3263  {"map":"de_overpass","patch_version":13740,"ma...         5                   2               -1                   1
# 38863  de_overpass         4        5       Normal               74.976560              400             492                     4                    5          3750.0          25250     11500    38600           False       NaN          True    Terrorist           7         3264  {"map":"de_overpass","patch_version":13740,"ma...         5                   2               -1                   1
# 38864  de_overpass         4        5       Normal               54.976562              300             360                     3                    5          3550.0          23150      9500    38900           False       NaN         False    Terrorist           7         3265  {"map":"de_overpass","patch_version":13740,"ma...         5                   2               -1                   1
# 38865  de_overpass         4        6   FreezeTime               19.875000              500             500                     5                    5          1000.0          22950     26150    55400           False       NaN         False           CT           7         3266  {"map":"de_overpass","patch_version":13740,"ma...         5                   1               -1                   0
# 38866  de_overpass         4        6       Normal              114.898440              500             500                     5                    5         26450.0          28350       700    50000           False       NaN         False           CT           7         3267  {"map":"de_overpass","patch_version":13740,"ma...         5                   2               -1                   0
# 38867  de_overpass         4        6       Normal               94.898440              500             482                     5                    5         24250.0          27450       700    50000           False       NaN         False           CT           7         3268  {"map":"de_overpass","patch_version":13740,"ma...         5                   2               -1                   0
# 38868  de_overpass         4        6       Normal               74.898440              500             371                     5                    4         23950.0          21850      1000    40650           False       NaN         False           CT           7         3269  {"map":"de_overpass","patch_version":13740,"ma...         5                   2               -1                   0
# 38869  de_overpass         4        6       Normal               54.835938              500             371                     5                    4         22850.0          21250      1000    40650           False       NaN         False           CT           7         3270  {"map":"de_overpass","patch_version":13740,"ma...         5                   2               -1                   0
# 38870  de_overpass         4        6       Normal               34.835938              500             371                     5                    4         21550.0          19450      1000    40650           False       NaN         False           CT           7         3271  {"map":"de_overpass","patch_version":13740,"ma...         5                   2               -1                   0
# 38871  de_overpass         4        6       Normal               14.835938              500             371                     5                    4         21050.0          18350      1000    40650           False       NaN         False           CT           7         3272  {"map":"de_overpass","patch_version":13740,"ma...         5                   2               -1                   0
# 38872  de_overpass         4        6  BombPlanted               33.406250              172             271                     2                    3          7900.0          14150       350    36150           False         B         False           CT           7         3273  {"map":"de_overpass","patch_version":13740,"ma...         5                   0                1                   0
# 38873  de_overpass         4        6  BombPlanted               13.406250              134               0                     2                    0          9550.0              0      1250        0           False         B         False           CT           7         3274  {"map":"de_overpass","patch_version":13740,"ma...         5                   0                1                   0
